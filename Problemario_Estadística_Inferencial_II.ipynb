# %% [markdown]
# <a href="https://colab.research.google.com/github/williamsabrahamflorianolara-boop/Estadistica2026B-1/blob/main/Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df=pd.DataFrame({
    "promedio_de_exámenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})

df
# Out:
#     promedio_de_exámenes_cortos  promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
#1 Establece una variable dependiente (y) e independiente (x)
y=df["promedio_final"]
x=df["promedio_de_exámenes_cortos"]

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'promedio_de_exámenes_cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'promedio_final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(x, y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.8646
# valor_p:  0.0000

# %%
import statsmodels.api as sm
x_constante= sm.add_constant(x)
modelo= sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)

modelo.params
# Out:
# const                          24.526822
# promedio_de_exámenes_cortos     0.643180
# dtype: float64

# %% [markdown]
# El modelo es:
#
# $$
# \hat{y}=24.5268+0.643180x
# $$
#
# donde $x$ es el promedio en examenes cortos

# %%
#Intervalos de confianza

modelo.conf_int(alpha=0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# promedio_de_exámenes_cortos  0.419219   0.867141

# %%
modelo.predict([1, 59])
# Out:
# array([62.47443345])

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'promedio_de_exámenes_cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'promedio_final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %%
residuales= modelo.resid

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada* 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'promedio_de_exámenes_cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#Test de Shapiro-Wilk
#Ho: hay normalidad
#Hi: no hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.901827735700704

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(x)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2289

# %%
#Test de ANOVA
#Ho: beta_1 = 0 (No hay correlacion)
#Hi: beta_1 ≠ 0 (Si hay correlacion)

from statsmodels.formula.api import ols
# y ~ x
modelo_lineal = ols("promedio_final~promedio_de_exámenes_cortos", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                df       sum_sq      mean_sq          F  \
# promedio_de_exámenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# promedio_de_exámenes_cortos  0.000032
# Residual                          NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df=pd.DataFrame({
    "ausencias":[18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31, 40],
    "salario":[11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8, 3],
})

df
# Out:
#     ausencias  salario
# 0          18       11
# 1          17       10
# 2          29        8
# 3          36        5
# 4          11        9
# 5          28        7
# 6          35        3
# 7          14       11
# 8          20        8
# 9          32        7
# 10         39        2
# 11         16        9
# 12         31        8
# 13         40        3

# %% [markdown]
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).

# %%
#1 Establece una variable dependiente (y) e independiente (x)
y=df["salario"]
x=df["ausencias"]

# %% [markdown]
# 2.   Realice un diagrama de dispersión para estos datos.

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %% [markdown]
# 3. **¿Los datos soportan la suposicion de linealidad?**
#
# Si

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(x, y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=-0.8801$, este valor indica que se rechaza la hipotesis nula, si hay correlacion

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante= sm.add_constant(x)
modelo= sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)

# %%
#Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(y, y_calculada)

print(f"Coeficiente de determinacion: {r2: 0.4f}")
# Out:
# Coeficiente de determinacion:  0.7746

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.7746$ indica que con las ausencias estoy justicando en un 77.46% la variabilidad en los salarios. Por lo que el modelo puede tener una buena capacidad de prediccion

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm
x_constante= sm.add_constant(x)
modelo= sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)

modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# El modelo es:
#
# $$
# \hat{y}=14.0588-0.261814x
# $$
#
# donde $x$ son las ausencias

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="+",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)
# Out:
# /tmp/ipykernel_7157/3184137508.py:11: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
#
# La recta forma: $$y= b_0 + b_1X$$

# %%
#Intervalos de confianza

modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# El verdadero $b_0$ esta entre $11.587445$ y $16.530241$ con una confianza del 95%. esto indica que una persona sin ausencias ($X=0$) tiene una categoria de salario ($Y$) que esta entre estos dos valores
#
# El verdadero valor de $b_1$ esta entre $-0.350638$ y $-0.172989$ con un 95% de confianza. Dado que de entre este intervalo no esta el valor de cero , entonces la relacion es significativa. Tambien indica que por cada falta se pierde entre 0.172989 y 0.350638 en la categoria de salario

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales= modelo.resid

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada* 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %% [markdown]
# Para los supuestos:
#
# *   Linealidad: Parece que si porque no esta tan lejos de la recta
# *   Normalidad: Si cumple con la normalidad, porque los puntos tienen buena dispersion
# *   Homoscedasticidad: Si cumple con la homoscedasticidad, porque caen similar en los dos lados de la recta
# *   Independencia: Si cumple, por que son diferentes personas

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#Test de Shapiro-Wilk
#Ho: hay normalidad
#Hi: no hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(x)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
#
#
#
# Si el modelo cumple con todos los supuestos, es confiable para interpolacion

# %%
#minimo ausencias: 11
#maximo ausencias: 40

#interpolar, valores de x entre 11 y 40

# interpolar
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict([1, 32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  7.5135
# Para x = 32, y =  5.6808

# %%
df["salario_predicho"] = y_calculada.round()

df
# Out:
#     ausencias  salario  salario_predicho
# 0          18       11               9.0
# 1          17       10              10.0
# 2          29        8               6.0
# 3          36        5               5.0
# 4          11        9              11.0
# 5          28        7               7.0
# 6          35        3               5.0
# 7          14       11              10.0
# 8          20        8               9.0
# 9          32        7               6.0
# 10         39        2               4.0
# 11         16        9              10.0
# 12         31        8               6.0
# 13         40        3               4.0

# %% [markdown]
# La extrapolacion  siempre debe hacerse con cuidado, aunque compla con todos los supuestos

# %%
#minimo ausencias: 11
#maximo ausencias: 40

#Extrapolar, valores de x que no estan entre 11 y 40

y_10 = modelo.predict([1, 10])

print(f"Para x = 10, y = {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =  11.4407

# %% [markdown]
# Con 10 ausencias se espera que el empleado tenga una categoria de salario de 11. Este valor se obtuvo por medio de extrapolacion, por lo que se toma con reservas

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
#Test de ANOVA
#Ho: beta_1 = 0 (No hay correlacion)
#Hi: beta_1 ≠ 0 (Si hay correlacion)

from statsmodels.formula.api import ols
# y ~ x
modelo_lineal = ols("salario~ausencias", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Si hay correlacion por que el valor-p de $0.000033$ es menor a un nivel de significancia $α=0.05$
#
# En los residuales del anova se puede ver

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df=pd.DataFrame({
    "gastos_generales":[191, 170, 272, 155, 280, 173, 234, 116, 153, 178],
    "unidades":[40, 42, 53, 35, 56, 39, 48, 30, 37, 40],
})

df
# Out:
#    gastos_generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %% [markdown]
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).

# %%
#1 Establece una variable dependiente (y) e independiente (x)
y=df["gastos_generales"]
x=df["unidades"]

# %% [markdown]
# 2.   Realice un diagrama de dispersión para estos datos.

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'gastos_generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %% [markdown]
# 3. **¿Los datos soportan la suposicion de linealidad?**
#
# Si

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(x, y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=0.9835$, este valor indica que se rechaza la hipotesis nula, si hay correlacion

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante= sm.add_constant(x)
modelo= sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)

# %%
#Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(y, y_calculada)

print(f"Coeficiente de determinacion: {r2: 0.4f}")
# Out:
# Coeficiente de determinacion:  0.9673

# %% [markdown]
# Con coeficiente de determinacion de $r^2=0.9673$ indica que con las ausencias estoy justicando en un 96.73% la variabilidad en los salarios. Por lo que el modelo puede tener una buena capacidad de prediccion

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm
x_constante= sm.add_constant(x)
modelo= sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %% [markdown]
# El modelo es:
#
# $$
# \hat{y}=-80.442857-6.491497x
# $$
#
# donde $x$ son las ausencias

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="+",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'gastos_generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)
# Out:
# /tmp/ipykernel_7157/2692972818.py:11: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
#
# La recta forma: $$y= b_0 + b_1X$$

# %%
#Intervalos de confianza

modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543

# %% [markdown]
# El verdadero $b_0$ esta entre $-121.986373$ y $-38.899341$ con una confianza del 95%. esto indica que las unidades ($X=0$) tiene una categoria de gastos generales ($Y$) que esta entre estos dos valores
#
# El verdadero valor de $b_1$ esta entre $5.518450$ y $7.464543$ con un 95% de confianza. Dado que de entre este intervalo no esta el valor de cero , entonces la relacion es significativa. Tambien indica que por cada unidad se pierde entre 0.126675 y 0.171347 en la categoria de gastos generales

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales= modelo.resid

# %%
#2 Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=80,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada* 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'gastos_generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='-',
    linewidth=0.7,
    alpha=0.5,
    color="green"
)

# %% [markdown]
# Para los supuestos:
#
# *   Linealidad: Parece que si porque no esta tan lejos de la recta
# *   Normalidad: Si cumple con la normalidad, porque los puntos tienen buena dispersion
# *   Homoscedasticidad: Si cumple con la homoscedasticidad, porque caen similar en los dos lados de la recta
# *   Independencia: Si cumple, por que son diferentes personas

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

#Test de Shapiro-Wilk
#Ho: hay normalidad
#Hi: no hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(x)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
#
#
#
# Si el modelo cumple con todos los supuestos, es confiable para interpolacion

# %%
#minimo unidades: 30
#maximo unidades: 56

#interpolar, valores de x entre 30 y 56

# interpolar
y_35 = modelo.predict([1, 35])
y_51 = modelo.predict([1, 51])

print(f"Para x = 25, y = {y_35[0]: 0.4f}")
print(f"Para x = 32, y = {y_51[0]: 0.4f}")
# Out:
# Para x = 25, y =  146.7595
# Para x = 32, y =  250.6235

# %%
df["gastos_generales_predicho"] = y_calculada.round()

df
# Out:
#    gastos_generales  unidades  gastos_generales_predicho
# 0               191        40                      179.0
# 1               170        42                      192.0
# 2               272        53                      264.0
# 3               155        35                      147.0
# 4               280        56                      283.0
# 5               173        39                      173.0
# 6               234        48                      231.0
# 7               116        30                      114.0
# 8               153        37                      160.0
# 9               178        40                      179.0

# %% [markdown]
# La extrapolacion  siempre debe hacerse con cuidado, aunque compla con todos los supuestos

# %%
#minimo ausencias: 30
#maximo ausencias: 56

#Extrapolar, valores de x que no estan entre 11 y 40

y_29 = modelo.predict([1, 29])

print(f"Para x = 29, y = {y_29[0]: 0.4f}")
# Out:
# Para x = 29, y =  107.8105

# %% [markdown]
# Con 29 unidades se espera que el empleado tenga una categoria de gastos generales de 107. Este valor se obtuvo por medio de extrapolacion, por lo que se toma con reservas

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
#Test de ANOVA
#Ho: beta_1 = 0 (No hay correlacion)
#Hi: beta_1 ≠ 0 (Si hay correlacion)

from statsmodels.formula.api import ols
# y ~ x
modelo_lineal = ols("gastos_generales~unidades", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    'construccion_de_casas': [2.0, 2.5, 3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0],
    'ventas_de_linea_blanca': [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0],
})

df
# Out:
#    construccion_de_casas  ventas_de_linea_blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0

# %% [markdown]
# 1.   **Establesca una variable dependiente ($Y$) y una variable independiente ($X$)**
#
# + $Y$: son las ventas porque dependen de la venta de casas
# + $X$: son las construcciones porque son independientes

# %%
# Y: salarios
# X: ausencias

X = df['construccion_de_casas']
Y = df['ventas_de_linea_blanca']

# %% [markdown]
# 2.   **Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construccion_de_casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'ventas_de_linea_blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**
#
# Sí, porque a simple vista parece seguir una recta

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlaciòn: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlaciòn:  0.9808
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=0.9808$, este valor indica que la correlación es fuerte, dado que está muy cerca de 1.

# %% [markdown]
# 5. **Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.19%

# %% [markdown]
# Con coeficiente de determinación de $$r^2=0.9619$$ indica que con las construcciones estoy justificando en un $96.19\%$ la variabilidad en las ventas. Por lo que el modelo puede tener una buena capacidad de predicción.

# %% [markdown]
# 6. **Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión**

# %%
modelo.params
# Out:
# const                    1.016760
# construccion_de_casas    1.737564
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=1.016760-	1.737564X
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construccion_de_casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'ventas_de_linea_blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma:
#
# $$\hat{y}=b_0+b_1X$$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# construccion_de_casas  1.455693  2.019435

# %% [markdown]
# El verdadero $b_0$ está entre $-0.074848$ y	$2.108368$ con una confianza del 95%. Esto indica que una construccion ($X=0$) tiene una categoría de ventas ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ está entre $1.455693$ y	$2.019435$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada construccion se pierde entre 1.455693 y	2.019435 en la categoría de ventas.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <--------------------------------------------------------
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construccion_de_casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
#
# + Linealidad: Parece que sí, porque los puntos no estan lejos de la recta
# + Normalidad: Sí cumple con la normalidad, porque la dispersion es buena
# + Homoscedasticidad: No cumple con la homoscedasticidad, porque no estan bien repartidos los puntos
# + Independencia: Sí cumple, porque son diferentes construcciones.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8463507249054649

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.1581

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %% [markdown]
# Si el modelo cumple con todos los supuestos, es confiable para interpolación.

# %%
# mínimo ausencias: 2.0
# máximo ausencias: 10.0

# interpolar, valores de x entre 2.0 y 10.0

# interpolar
y_40 = modelo.predict([1, 4.0])
y_75 = modelo.predict([1, 7.5])

print(f"Para x = 4.0, y =  {y_40[0]: 0.4f}")
print(f"Para x = 7.5, y =  {y_75[0]: 0.4f}")
# Out:
# Para x = 4.0, y =   7.9670
# Para x = 7.5, y =   14.0485

# %%
df["salario_predicho"] = y_calculada.round()
df
# Out:
#    construccion_de_casas  ventas_de_linea_blanca  salario_predicho
# 0                    2.0                     5.0               4.0
# 1                    2.5                     5.5               5.0
# 2                    3.2                     6.0               7.0
# 3                    3.6                     7.0               7.0
# 4                    3.7                     7.2               7.0
# 5                    4.0                     7.7               8.0
# 6                    4.2                     8.4               8.0
# 7                    4.6                     9.0               9.0
# 8                    4.8                     9.7               9.0
# 9                    5.0                    10.0              10.0

# %%
# mínimo ausencias: 2.0
# máximo ausencias: 10.0

# Extrapolar, valores de x que no estén entre 11 y 40

y_60 = modelo.predict([[1, 6.0]])

print(f"Para x = 6.0, y =  {y_60[0]: 0.4f}")
# Out:
# Para x = 6.0, y =   11.4421

# %% [markdown]
# Con 6.0 construcciones se espera que la liena blanca tenga una categoría de ventas de 11. Este valor se obtuvo por medio de extrapolación, por lo que se toma con reservas.

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''ventas_de_linea_blanca ~ construccion_de_casas''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df     sum_sq    mean_sq           F        PR(>F)
# construccion_de_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual               8.0   1.028419   0.128552         NaN           NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $5.841003e-07$ es menor a un nivel de significancia $\alpha=0.05$.
#
# En los residuales del anova se puede ver

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    'numero_interrupciones': [5, 10, 10, 15, 15, 20, 20, 25],
    'calificacion_prueba_de_hostilidad': [58, 41, 45, 27, 26, 12, 16, 3],
})

df
# Out:
#    numero_interrupciones  calificacion_prueba_de_hostilidad
# 0                      5                                 58
# 1                     10                                 41
# 2                     10                                 45
# 3                     15                                 27
# 4                     15                                 26
# 5                     20                                 12
# 6                     20                                 16
# 7                     25                                  3

# %% [markdown]
# 1.   **Establesca una variable dependiente ($Y$) y una variable independiente ($X$)**
#
# + $Y$: es la calificacion porque depende del numero de interrupciones
# + $X$: son las interrupciones porque estas son el motivo de la prueba

# %%
# Y: calificacion
# X: interrupciones

X = df['numero_interrupciones']
Y = df['calificacion_prueba_de_hostilidad']

# %% [markdown]
# 2.   **Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'numero_interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificacion_prueba_de_hostilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**
#
# Sí, porque aparentemente sigue una linea recta

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlaciòn: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlaciòn: -0.9928
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=-0.9928$, este valor indica que la correlación es fuerte, dado que está muy cerca de 1. Además, el que sea negativa, implica que aumentar las interrupciones ($X$) disminuye la hostilidad ($Y$).

# %% [markdown]
# 5. **Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  98.58%

# %% [markdown]
# Con coeficiente de determinación de $$r^2=0.9858$$ indica que con las interrupciones estoy justificando en un $98.58\%$ la variabilidad en la hostilidad. Por lo que el modelo puede tener una buena capacidad de predicción.

# %% [markdown]
# 6. **Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión**

# %%
modelo.params
# Out:
# const                    70.5
# numero_interrupciones    -2.8
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=	70.5-2.8X
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'numero_interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificacion_prueba_de_hostilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma:
#
# $$\hat{y}=b_0+b_1X$$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                0          1
# const                  65.051384  75.948616
# numero_interrupciones  -3.136296  -2.463704

# %% [markdown]
# El verdadero $b_0$ está entre $65.051384$ y	$75.948616$ con una confianza del 95%. Esto indica que una persona sin interrupciones ($X=0$) tiene una categoría de hostilidad ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ está entre $-3.136296$ y	$-2.463704$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada interrupcion se pierde entre -3.136296	y -2.463704 en la categoría de hostilidad.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <--------------------------------------------------------
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'numero_interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
#
# + Linealidad: Parece que no, porque no estan cerca de la recta
# + Normalidad: Sí cumple con la normalidad, porque tienen una dispersion rara
# + Homoscedasticidad: Sí cumple con la homoscedasticidad, porqueaparentemente estan de los dos lados de la recta
# + Independencia: Sí cumple, porque son diferentes construcciones.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2482

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %% [markdown]
# Si el modelo cumple con todos los supuestos, es confiable para interpolación.

# %%
# mínimo ausencias: 2
# máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict([1, 32])

print(f"Para x = 25, y =  {y_25[0]: 0.4f}")
print(f"Para x = 32, y =  {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =   0.5000
# Para x = 32, y =  -19.1000

# %%
df["hostilidad_predicho"] = y_calculada.round()
df
# Out:
#    numero_interrupciones  calificacion_prueba_de_hostilidad  \
# 0                      5                                 58
# 1                     10                                 41
# 2                     10                                 45
# 3                     15                                 27
# 4                     15                                 26
# 5                     20                                 12
# 6                     20                                 16
# 7                     25                                  3
#
#    hostilidad_predicho
# 0                 56.0
# 1                 42.0
# 2                 42.0
# 3                 28.0
# 4                 28.0
# 5                 15.0
# 6                 15.0
# 7                  1.0

# %% [markdown]
# La extrapolación siempre debe hacerse con cuidado, aunque cumpla con todos los supuestos.

# %%
# mínimo ausencias: 2
# máximo ausencias: 40

# Extrapolar, valores de x que no estén entre 2 y 40

y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y =  {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =   42.5000

# %% [markdown]
# Con 10 ausencias se espera que el empleado tenga una categoría de hostilidad de 42. Este valor se obtuvo por medio de extrapolación, por lo que se toma con reservas.

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''calificacion_prueba_de_hostilidad ~ numero_interrupciones''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df  sum_sq      mean_sq           F        PR(>F)
# numero_interrupciones  1.0  2352.0  2352.000000  415.058824  9.090964e-07
# Residual               6.0    34.0     5.666667         NaN           NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $9.090964e-07$ es menor a un nivel de significancia $\alpha=0.05$.
#
# En los residuales del anova se puede ver...
